# %% [markdown]
# # Long-Term Trend Significance and EVT Profiling
#
# This notebook covers the statistical evaluation of Marine Heatwave frequency and intensity trends over the 1982-2024 period. We utilize Mann-Kendall tests for trend significance, STL decomposition to isolate warming from ENSO cyclic noise, and Extreme Value Theory (EVT) to model return periods.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import Image

plt.style.use('seaborn-v0_8-whitegrid')
sns.set_context("notebook", font_scale=1.2)

# %% [markdown]
# ## 1. Mann-Kendall Trend Significance

# %%
df_mk = pd.read_csv('../data/processed/trend_significance_mk_theilsen.csv')
print("Mann-Kendall Trend Results:")
display(df_mk)

# %% [markdown]
# ## 2. Seasonal-Trend Decomposition (STL)

# %% [markdown]
# By decomposing the time series, we isolate the underlying warming trend from both regular seasonal variations and large interannual residual shocks (like El Niño).

# %%
Image(filename='../figures/stl_decomposition_frequency_duration.png')

# %% [markdown]
# ## 3. Extreme Value Theory Projections (GEV)

# %% [markdown]
# We apply the Generalized Extreme Value (GEV) distribution to annual block-maxima to model the return levels of future extreme MHW intensity.

# %%
Image(filename='../figures/evt_fit_mhw_intensity.png')

# %% [markdown]
# ## 4. Decadal Summary

# %%
df_decadal = pd.read_csv('../data/processed/table_decadal_summary.csv')
display(df_decadal)
